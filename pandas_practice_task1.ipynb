# %% [markdown]
# <a href="https://colab.research.google.com/github/ByteForge-sg/EDAlab/blob/main/pandas_practice_task1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#TASK1
import numpy as np
import pandas as pd

employee_data = {
    "EmployeeID": [101,102,103,104,105,106,107,108,109,110],
    "Name": [
        "John",
        "Smith",
        "Alex",
        "Emma",
        "David",
        "Chris",
        "Sarah",
        "Mike",
        "Anna",
        "Robert"
    ],
    "Department": [
        "HR",
        "IT",
        "Finance",
        "IT",
        "HR",
        "Finance",
        "IT",
        "Marketing",
        "HR",
        "Finance"
    ],
    "Age": [25,30,35,28,40,32,27,29,38,45],
    "Salary": [
        45000,
        55000,
        75000,
        60000,
        90000,
        70000,
        50000,
        65000,
        85000,
        100000
    ]
}

df=pd.DataFrame(employee_data)
df.to_csv("employee_data.csv",index=False)

emp_df=pd.read_csv("employee_data.csv")

#1. display first 5 rows
print(emp_df.head())
print()
print()
#2. display last 5 rows
print(emp_df.tail())
#3.print the shape
print()
print()
print(emp_df.shape)
# Out:
#    EmployeeID   Name Department  Age  Salary
# 0         101   John         HR   25   45000
# 1         102  Smith         IT   30   55000
# 2         103   Alex    Finance   35   75000
# 3         104   Emma         IT   28   60000
# 4         105  David         HR   40   90000
#
#
#    EmployeeID    Name Department  Age  Salary
# 5         106   Chris    Finance   32   70000
# 6         107   Sarah         IT   27   50000
# 7         108    Mike  Marketing   29   65000
# 8         109    Anna         HR   38   85000
# 9         110  Robert    Finance   45  100000
#
#
# (10, 5)

# %%
#TASK2
import numpy as np
import pandas as pd

employee_data = {
    "EmployeeID": [101,102,103,104,105,106,107,108,109,110],
    "Name": [
        "John",
        "Smith",
        "Alex",
        "Emma",
        "David",
        "Chris",
        "Sarah",
        "Mike",
        "Anna",
        "Robert"
    ],
    "Department": [
        "HR",
        "IT",
        "Finance",
        "IT",
        "HR",
        "Finance",
        "IT",
        "Marketing",
        "HR",
        "Finance"
    ],
    "Age": [25,30,35,28,40,32,27,29,38,45],
    "Salary": [
        45000,
        55000,
        75000,
        60000,
        90000,
        70000,
        50000,
        65000,
        85000,
        100000
    ]
}

df=pd.DataFrame(employee_data)
df.to_csv("employee_data.csv",index=False)

emp_df=pd.read_csv("employee_data.csv")
#1.column names
print(emp_df.columns)
print()
print()
#2. datatypes
print(emp_df.dtypes)

#3. information
print()
print()
print(emp_df.info())

#4. decribe funvtion get mathematical values
print()
print()
print(emp_df.describe())
# Out:
# Index(['EmployeeID', 'Name', 'Department', 'Age', 'Salary'], dtype='object')
#
#
# EmployeeID     int64
# Name          object
# Department    object
# Age            int64
# Salary         int64
# dtype: object
#
#
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10 entries, 0 to 9
# Data columns (total 5 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   EmployeeID  10 non-null     int64
#  1   Name        10 non-null     object
#  2   Department  10 non-null     object
#  3   Age         10 non-null     int64
#  4   Salary      10 non-null     int64
# dtypes: int64(3), object(2)
# memory usage: 532.0+ bytes
# None
#
#
#        EmployeeID        Age         Salary
# count    10.00000  10.000000      10.000000
# mean    105.50000  32.900000   69500.000000
# std       3.02765   6.436873   18020.050561
# min     101.00000  25.000000   45000.000000
# 25%     103.25000  28.250000   56250.000000
# ...

# %%
#TASK 3
import numpy as np
import pandas as pd

employee_data = {
    "EmployeeID": [101,102,103,104,105,106,107,108,109,110],
    "Name": [
        "John",
        "Smith",
        "Alex",
        "Emma",
        "David",
        "Chris",
        "Sarah",
        "Mike",
        "Anna",
        "Robert"
    ],
    "Department": [
        "HR",
        "IT",
        "Finance",
        "IT",
        "HR",
        "Finance",
        "IT",
        "Marketing",
        "HR",
        "Finance"
    ],
    "Age": [25,30,35,28,40,32,27,29,38,45],
    "Salary": [
        45000,
        55000,
        75000,
        60000,
        90000,
        70000,
        50000,
        65000,
        85000,
        100000
    ]
}

df=pd.DataFrame(employee_data)
df.to_csv("employee_data.csv",index=False)

emp_df=pd.read_csv("employee_data.csv")

print(emp_df.isnull().sum()) #missing values
#missing percentage
missing_percentage=(emp_df.isnull().sum())/len(emp_df)*100
print(missing_percentage)

#duplicates
clean_df=emp_df.drop_duplicates()
print()
print()
print(clean_df)
# Out:
# EmployeeID    0
# Name          0
# Department    0
# Age           0
# Salary        0
# dtype: int64
# EmployeeID    0.0
# Name          0.0
# Department    0.0
# Age           0.0
# Salary        0.0
# dtype: float64
#
#
#    EmployeeID    Name Department  Age  Salary
# 0         101    John         HR   25   45000
# 1         102   Smith         IT   30   55000
# 2         103    Alex    Finance   35   75000
# 3         104    Emma         IT   28   60000
# 4         105   David         HR   40   90000
# 5         106   Chris    Finance   32   70000
# 6         107   Sarah         IT   27   50000
# 7         108    Mike  Marketing   29   65000
# 8         109    Anna         HR   38   85000
# 9         110  Robert    Finance   45  100000
